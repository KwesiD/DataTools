# %%
from species_generator import generate_species
from name_generator import generate_names,convert_name,standard_formats
import pandas as pd
import random

# %%
frame_columns = ["PatientName","Attendings","IPCStaff","Pathogen"] 

patient_info = pd.DataFrame(columns=frame_columns) #init a blank table
num_patients = 100 
patient_names = generate_names(100,"f l") #create the set of patient names
attendings_names = generate_names(30,"f m l") #attending full names
ipc_names = generate_names(20,"f m l") #ipc member full names

for patient in patient_names:
    patient = convert_name(patient,"f l",'l, f')
    #pick a random attending and random name format
    curr_attending = convert_name(random.choice(attendings_names),"f m l","mix")
    #do the same for a random number of staff
    curr_staff = random.choices(ipc_names,k=random.randint(1,5))
    for i in range(len(curr_staff)):
        curr_staff[i] = convert_name(curr_staff[i],"f m l","mix")
    curr_staff = ";".join(curr_staff)
    #generate a random pathogen
    curr_pathogen = ";".join(generate_species(random.randint(1,3),bool(random.randint(1,1))))
    #append row to data frame
    row = [patient,curr_attending,curr_staff,curr_pathogen]
    patient_info = patient_info.append(pd.DataFrame([row],columns=frame_columns),ignore_index = True)

# %%
patient_info
# Out:
#             PatientName                     Attendings  \
# 0         Lorrin Spring                 Margaitis, C C
# 1      Rachele Pelcyger                  Fran N Coombs
# 2         Andeee Millet            Fey Gradeigh Demusz
# 3         Erinn Ahlfors                 Chernin, Vevay
# 4        Cally Scranton                     Jorie Goff
# 5          Emma Kemmett              Posner, Eolanda H
# 6       Velvet Aricanli               Gussi E Knypstra
# 7            Randy Zani                        S Heiss
# 8          Gladi Chisom                 Fenster, Barbi
# 9     Celestina Brenner                   Anitra Lehar
# 10          Dredi Hanna                        E Chary
# 11         Maritsa Kolb                     K Assuncao
# 12     Claudette Malmon                   Riess, Leora
# 13        Nonna Ghysels                       E Posner
# 14      Ginny Calvaruso                     Colby, M R
# 15       Alanna Seyfert                 Heiss, Salli C
# 16         Melodee Drum                  Demoney, Rivy
# 17       Christa Curtin                    Hanson, F D
# 18        Corissa Solow                 Toole, Jacenta
# 19       Leann Trumbull           Assuncao, Kathryne A
# 20         Ivie Collard                Demoney, Rivy R
# 21   Cindra Rauffenbart                   Abbie G Page
# 22         Vonnie Power             Wollitzer, Ariella
# 23        Cecile Sterne            Fey Gradeigh Demusz
# 24         Jodee Heanue        Priscilla Isa Demirjian
# 25          Corey Emory               Lavina H Hawkins
# 26     Gloriana Woolley             Salli Cassie Heiss
# 27        Dulci Zevitas                     Chary, E R
# 28         Irena Eccles                    L Arakelian
# 29        Vina Shorrock       Ariella Carson Wollitzer
# ..                  ...                            ...
# 70        Freddie Doner                     D Eskridge
# 71        Melody Slowey           Demirjian, Priscilla
# 72        Kippie Seldin                     Toole, J B
# 73       Shaina Tiffany                 Maryanna Colby
# 9   Apatides fzrtix;Ulloterppsis semialata;Solanum...
# 10                                Adoxa moschVtellina
# 11                                     Conus striatus
# 12  Citrus hystrix;Flaveria linearis;LecVobacillus...
# 13                                     DioHpyros kaki
# 14  Bitis gabonicf;Drosophila funebris;Passer hisp...
# 15  Cynopterus bracbyotir;HetPromys aBomalus;MelSn...
# 16                                 Chaerephhn chapini
# 17              Lepus mandshuricKs;LoriNs albiQinucha
# 18                 Ixodes nicinus;Klternwria botrytis
# 19        Corynebacterium nephridii;CaXsicum chinenGe
# 20                                   Spinus Vawrencei
# 21                      Sphyrna zygaena;Tichelia alma
# 22         CapshcuY bBccatum;Actinoplares liguriensis
# 23  Branchiosthma floridae;Persicaria aQphibda;Pas...
# 24  Cgicetulus griseus;Bolitoglossa altamazonica;M...
# 25                               Antennarics striatus
# 26           KlaCnedoxa ganonensis;Calohys musculinus
# 27               Trichopodus Neerii;Callithrix kuhlii
# 28  Lilaeopsis nJvaezolandPae;VirMo pluLbeus;Dxrof...
# 29                                 Chamaerops humilis
# ..                                                ...
# 70           Pycnoporus coccineut;Damalyscus pygarQus
# 71            PrJstolepis fasciata;Anoplopoma fimfria
# 72  Serratia MubidKea;TheilerXa mutans;CarEamine f...
# 73                                 Cxrysiptera cyaPea
# 74     CbortOipqus olbomarginatus;Periplaneta brunnea
# 75                                  Takifugu oCscuyus
# 76               Melica altissima;Jasmieum nudiflorum
# 77  Cidixdela rofLvectris;Tectaria devexa;Polyplec...
# 78                        HeteroGontus pHrtusjacksonN
# 79                              Bionectria ochroleuca
# 80  TadGrida insignis;StreKtomyces globisporus;Ure...
# 81             Bubagus myudorensin;Vlphitonia LxcwlsF
# 82         Lepidochelys olivacoa;MeliAara prodenialis
# 83  Phaps cDalcopfera;Diglymma clivinEides;PhycFod...
# 84  RhodnCus robustus;Leuconostoc oelidum;Cartoder...
# 85                                Solanum macrocarpOn
# 86              Praomys misonnei;Hagenius brePiqtylus
# 87                                 Alpheus panamecsis
# 88                             Panulzrus peHicKllatus
# 89  Erithacus SubeBula;Pachybandra procumbens;Hapl...
# 90            Neotoma fuscipes;IchthWophiC bannanicus
# 91  vufotes viridis;Glironia vAnbsta;PaKmlio consb...
# 92         AnartDa jatrophar;Phyllncanthus Fmperialis
# 93              Melita plumulosa;Dicksonia antarcNica
# 94  Poeciliopsis occidentalis;MicheUia alba;Herico...
# 95           Chironomus annularius;Triatoma prTtraIta
# 96  Meghimatiul fruhstoQferi;Ampithok longimana;Up...
# 97  LaruC cPchinnans;Colaptes rupicola;Diabrotica ...
# 98                Myatis aavidii;Phaethosnis eurynome
# 99                                TreponeMa denhicola
#
# [100 rows x 4 columns]
