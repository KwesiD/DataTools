# %%
from species_generator import generate_species
from name_generator import generate_names,convert_name,standard_formats
import pandas as pd
import random

# %%
frame_columns = ["PatientName","Attendings","IPCStaff","Pathogen"] 

patient_info = pd.DataFrame(columns=frame_columns) #init a blank table
num_patients = 100 
patient_names = generate_names(100,"f l") #create the set of patient names
attendings_names = generate_names(30,"f m l") #attending full names
ipc_names = generate_names(20,"f m l") #ipc member full names

for patient in patient_names:
    patient = convert_name(patient,"f l",'l, f')
    #pick a random attending and random name format
    curr_attending = convert_name(random.choice(attendings_names),"f m l","mix")
    #do the same for a random number of staff
    curr_staff = random.choices(ipc_names,k=random.randint(1,5))
    for i in range(len(curr_staff)):
        curr_staff[i] = convert_name(curr_staff[i],"f m l","mix")
    curr_staff = ";".join(curr_staff)
    #generate a random pathogen
    curr_pathogen = ";".join(generate_species(random.randint(1,3),bool(random.randint(1,1))))
    #append row to data frame
    row = [patient,curr_attending,curr_staff,curr_pathogen]
    patient_info = patient_info.append(pd.DataFrame([row],columns=frame_columns),ignore_index = True)

# %%
patient_info
# Out:
#               PatientName                   Attendings  \
# 0      Revlin, Fredericka                      L Remey
# 1         Hartmann, Caril                      H Moody
# 2     Ferraroni, Kerianne                Sikorski, B B
# 3          Sezer, Janella                     A Twomey
# 4          Sweeting, Etty            Allaway, Fayina T
# 5          Metaxas, Kacie                  I Bustillos
# 6          Hawkes, Kendra                Sikorski, B B
# 7      Pineheiro, LaVerne                   Perlo, B C
# 8      Lindquist, Marylee          Katharine A Galison
# 9       Nevelson, Jessica           Cindi Omar Wetmore
# 10       Camillo, Roselia              Warner, Cacilie
# 11        Rankine, Cristi              Lucev, Danika G
# 12           Dodge, Vanda  Britney Demetrius Sutradhar
# 13          Strange, Aile            Martinez-Ramos, E
# 14          Tiago, Dalila       Cacilie Wayland Warner
# 15        Denison, Joeann        Fayina Tybalt Allaway
# 16        Wegman, Felecia                Darlington, S
# 17         ruis, Christen                  Warner, C W
# 18        Rankine, Carmon           Galison, Katharine
# 19       Sharples, Orelle               Alhberg, Marga
# 20         Flaxman, Vanna            Friederike J Aron
# 21  Foreman-Fowler, Bunni              Mcnair, Bernita
# 22          Coogan, Tommy                    Deacon, V
# 23           Steen, Matti           Blakeley N fischer
# 24        Wegman, Petrina            Lorette M Tiemann
# 25      Kronecker, Bunnie                      Aron, F
# 26     Magliozzi, Rachael             Bernita X Mcnair
# 27        Valelly, Babita             Tiemann, Lorette
# 28        Jenneve, Annora                   Marazzi, M
# 29         Hackman, Licha      Lissy Bartholomew Remey
# ..                    ...                          ...
# 70     Besancon, Shirleen        Martinez-Ramos, Edita
# 71         Stotsky, Minna              Tracie Prezelin
# 72       Schrauwen, Noell        Martinez-Ramos, Edita
# 73        Tenney, Maritsa                     E Debold
# 74     Mccrickerd, Loleta            Katharine Galison
# 75      Harrison, Jaquith               Debold, Elaine
# 76       Arellano, Stormy                 Sutradhar, B
# 77         Mercier, Helyn                Cindi Wetmore
# 78      Eltinge, Brittani             Blakeley fischer
# 79      Chiang, Doralynne                    C Wetmore
# 80     Badulescu, Scarlet                   Moody, H F
# 81        Keohan, Mirilla                    K Galison
# 82       Mezzenga, Madlin                   Zhang, E C
# 83         Diamond, Ertha        Arabella Lorens Wentz
# 84        Sacher, Merissa            Ivory S Bustillos
# 85     Whitehorn, Deloris                Saree Mitnick
# 86          Herbert, Leda             Beyer, Jacquette
# 95                                       Cybil Ammons
# 96                                          D Goodall
# 97  Maude Sidney Dyson;H Klint;D Kooris;Prothero, ...
# 98  Prodromou, F;V Piran;Bertha N Prothero;Mcfadde...
# 99                 Mcfadden, Annamarie;Halley K Klint
#
#                                              Pathogen
# 0      Sicarius terrosus;FerviGobacterium pvnnivoraps
# 1                                    Cogus tessulatVs
# 2                                     Spsrula spiOula
# 3                             Halobacterium saMinarum
# 4     hajlophyllum thaFictroides;Paubrasilia echinata
# 5             BalgZnopIera omuraw;Batophera oerstedii
# 6   Sxrix uralYnsis;gerivouly pellucida;Pipilo chl...
# 7                              Passiflora amethystina
# 8   Phallus hadriani;Loxocorone alhax;DiaphoriwH c...
# 9                 Ogcocephalcs kaQvus;IpXmoea batatas
# 10                      Rhizozium loti;Mustelus canis
# 11  Diplacus aurantiacuO;bBletodon kleinii;ErpeWoi...
# 12                  Alouatta sara;Capsicum frutesceUs
# 13                         Heliocidaris eryQhcogramma
# 14  Magnolia virginiana;Elodia flavipalpis;Salmone...
# 15                                   POucaea cassinii
# 16  TydemakiC navwgatoris;Aphrodhora cMxbrata;Kleb...
# 17              Conus inscriptus;SminthoDsis douglasi
# 18  Lactobacillus fermentum;SargPcentron mtcHostom...
# 19  ueliobacterium cslorum;Flaveria pubescens;Scyt...
# 20       Bacillus azotofQrmans;DPyobalawops aromatica
# 21                                       Moho nobilis
# 22  ACxenYchlorHlla protothecoides;HeucinWthrips f...
# 23                                 Holothqria nobilis
# 24  Boreus elegans;Helobdella robusta;Conus regularis
# 25                                       Tamias rufus
# 26                Epichloe elymi;CeraKtium glomeratum
# 27                            Vaucocytozoon caulleryi
# 28                           GalliralkVs Nhilippqnsis
# 29                iundamys muelleei;Sepia officinalis
# ..                                                ...
# 70  Embalnonurq monticoDa;Potamopycgus antipedarum...
# 71                                   Thhlogale brhnii
# 72  CoUtus gobio;RYyzopertha dominica;CiEindela fa...
# 73                                Lathyrus littoraIis
# 74     OiceIptoma subrbfum;Methylobacillus glycogenes
# 75                           Epndermopnyton floccosus
# 76  Tipula oleracea;Cypseloidos niger;Streptoallot...
# 77  Bubo magellanicus;Centropyge tibiceV;AtropFide...
# 78  Lupinus argenteus;HelicoveFpa punctigera;Mssop...
# 79                                Zeugodacus caudatus
# 80  Clostridium acidurici;Culithemis elisa;Isatis ...
# 81                             Greenmanmella resinosa
# 82                             BHthygobius cocosensis
# 83  BrouZhDonia sanguinea;lhanera aaKiegata;Calidr...
# 84          Alaucaria cunoinghamii;Petxogale concinna
# 85                        NeocZauliodes punctatolXsus
# 86           Aeqypodius arfakianus;Posealax rgfescens
# 87  BQiHa maxima;XeOcariephoenix madagasiTrieNsis;...
# 88  SderuophOlus erytlrogenys;Thricopz semicinereu...
# 89  FqanciFella vuzarensis;TridScna maxima;Abraxas...
# 90  etNnophorus adelaidensio;UocciBella hieyoglyphica
# 91               Coenopoeus palmeri;Melilftus indicus
# 92  Gromphadorhina caeEigata;Salix viminalis;Eryx ...
# 93       Xiphinema divegsicaudatum;Oryzias celebCnsis
# 94  Wallabia bicRlor;LachancHa fTrmemCati;AsthYmSi...
# 95       Lophius piscatorius;ChauliodFs XectinicWrniR
# 96                                 Rhingim campeLtris
# 97               Aphanius iberus;Calanthe trLcarinata
# 98                              MegascopZ Vlbogularis
# 99  Hxdra virzdistima;GerbeRa hybrida;zalonectris ...
#
# [100 rows x 4 columns]
